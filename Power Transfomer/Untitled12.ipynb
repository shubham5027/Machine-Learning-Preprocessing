# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('concrete_data.csv')

# %%
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
Y=df['Strength']
X=df.drop(['Strength'],axis=1)
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# BOX-Cox transfom -strictly used for data having values greater than 0.(by default standadization is apply)
#
# YEO-Johnson- can applid to negative values and zero also by default stdadization is applied (more in favor)

# %%
pt1=PowerTransformer(method='box-cox')
pt2=PowerTransformer(method='yeo-johnson')

# %%
#Error During Box-Cox due to Negative Values
X_train_transform=pt1.fit_transform(X_train)
X_test_transform=pt1.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-75622b016b20> in <cell line: 1>()
# ----> 1 X_train_transform=pt1.fit_transform(X_train)
#       2 X_test_transform=pt1.transform(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in fit_transform(self, X, y)
#    3101         """
#    3102         self._validate_params()
# -> 3103         return self._fit(X, y, force_transform=True)
#    3104
#    3105     def _fit(self, X, y=None, force_transform=False):
#
# ...

# %%
# Box-Cox
X_train_transform=pt1.fit_transform(X_train+0.00001) #dont be zero or negative in box-cox
X_test_transform=pt1.transform(X_test+0.00001)

# %%
# Yeo-Johnson
X_train_transform_y=pt2.fit_transform(X_train) #no proble direct run yeo-johnson
X_test_transform_y=pt2.transform(X_test)
