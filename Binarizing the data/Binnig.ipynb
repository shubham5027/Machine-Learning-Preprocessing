# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import Binarizer
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('train.csv',usecols=['Age','Fare','Survived','SibSp','Parch'])

# %%
df.dropna(inplace=True)

# %%
df['family']=df['SibSp']+df['Parch']

# %%
df2=df.drop(['SibSp','Parch'],axis=1)

# %%
X=df2.drop(['Survived'],axis=1)
Y=df2['Survived']

X.isnull().sum()
# Out:
# Age       0
# Fare      0
# family    0
# dtype: int64

# %%
Y.isnull().sum()
# Out:
# 0

# %%
X_train,X_tet,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)
X_train
# Out:
#       Age      Fare  family
# 387  36.0   13.0000       0
# 685  25.0   41.5792       3
# 20   35.0   26.0000       0
# 331  45.5   28.5000       0
# 396  31.0    7.8542       0
# ..    ...       ...     ...
# 883  28.0   10.5000       0
# 238  19.0   10.5000       0
# 789  46.0   79.2000       0
# 704  26.0    7.8542       1
# 856  45.0  164.8667       2
#
# [571 rows x 3 columns]

# %%
bin=Binarizer()

# %%
X_train_bin=bin.fit_transform(X_train[['family']]
                              )
X_test_bin=bin.transform(X_test[['family']])

# %%
df3=pd.DataFrame(X_train_bin,columns=['family_new'])

# %%
df3['family_new']

# %%
X_train['familynew']=df3['family_new']

# %%
X_train
# Out:
#       Age      Fare  family  family_new
# 387  36.0   13.0000       0         0.0
# 685  25.0   41.5792       3         NaN
# 20   35.0   26.0000       0         1.0
# 331  45.5   28.5000       0         0.0
# 396  31.0    7.8542       0         1.0
# ..    ...       ...     ...         ...
# 883  28.0   10.5000       0         NaN
# 238  19.0   10.5000       0         0.0
# 789  46.0   79.2000       0         NaN
# 704  26.0    7.8542       1         NaN
# 856  45.0  164.8667       2         NaN
#
# [571 rows x 4 columns]
