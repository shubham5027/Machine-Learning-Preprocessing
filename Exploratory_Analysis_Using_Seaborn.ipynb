# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style='darkgrid')

# %%
df=pd.read_csv('heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# Relational Plot

# %%
sns.relplot(data=df,x='MaxHR',y='Age')

# %%
sns.relplot(data=df,x='Age',y="MaxHR",hue="Sex")

# %%
sns.relplot(data=df,x='Age',y="MaxHR",hue="Sex",kind='line')

# %% [markdown]
# Displots

# %%
sns.displot(data=df,x='Age',hue="Sex")

# %%
sns.displot(data=df,x='Age',kde='False')

# %% [markdown]
# Jointplot
#
# sns.jointplot(df,x="MaxHR",y="RestingBP",kind='kde')
#
# sns.jointplot(df,x="MaxHR",y="RestingBP",kind='reg')
#
# sns.jointplot(df,x="MaxHR",y="RestingBP",kind='hex')

# %%
sns.jointplot(df,x="MaxHR",y="RestingBP",kind='reg')

# %%
sns.jointplot(df,x="MaxHR",y="RestingBP",kind='hex')

# %%
sns.jointplot(df,x="MaxHR",y="RestingBP",kind='kde')

# %% [markdown]
# PairPlot
#
# sns.pairplot(df)
#
# sns.pairplot(df,hue='Sex')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Sex')

# %% [markdown]
# Catogorical plot
#
# sns.catplot(data=df,x='',y='',hue='',kind='swarm')
#
# sns.catplot(data=df,x='',y='',hue='',kind='boxen')
#
# sns.catplot(data=df,x='',y='',hue='',kind='violin')
#
# sns.catplot(data=df,x='',y='',hue='',kind='bar')
#
# sns.catplot(data=df,x='',y='',hue='',kind='count')
#
# sns.catplot(data=df,x='',y='',hue='',kind='point')
#
# sns.catplot(data=df,x='',y='',hue='',kind='box')

# %%
sns.catplot(data=df,x='MaxHR',y='RestingBP',hue='Sex',kind='swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(data=df,x='MaxHR',y='Age',hue='Sex',kind='swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(data=df,x='RestingBP',hue='Sex',kind='box')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-5ab9ad9567a7> in <cell line: 1>()
# ----> 1 sns.catplot(data=df,x='RestingBP',hue='Sex',kind='box')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3257
#    3258     if legend and (hue is not None) and (hue not in [x, row, col]):
# -> 3259         hue_order = list(map(utils.to_utf8, hue_order))
#    3260         g.add_legend(title=hue, label_order=hue_order)
#    3261
#
# TypeError: 'NoneType' object is not iterable

# %%
sns.catplot(data=df,x='MaxHR',hue='Sex',kind='violin')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-2437469a7e86> in <cell line: 1>()
# ----> 1 sns.catplot(data=df,x='MaxHR',hue='Sex',kind='violin')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3257
#    3258     if legend and (hue is not None) and (hue not in [x, row, col]):
# -> 3259         hue_order = list(map(utils.to_utf8, hue_order))
#    3260         g.add_legend(title=hue, label_order=hue_order)
#    3261
#
# TypeError: 'NoneType' object is not iterable

# %%
sns.catplot(data=df,x='MaxHR',y='Age',hue='Sex',kind='point')

# %%
sns.catplot(data=df,x='RestingBP',kind='count')
sns.catplot(data=df,x='MaxHR',kind='count')

# %%
sns.catplot(data=df,x='MaxHR',y='Age',hue='Sex',kind='bar')

# %%
sns.catplot(data=df,x='MaxHR',kind='box')
sns.catplot(data=df,x='RestingBP',kind='boxen')
sns.catplot(data=df,x="Cholesterol",kind='box')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >
